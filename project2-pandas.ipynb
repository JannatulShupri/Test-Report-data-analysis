# %%
import pandas as pd

# %%
df = pd .read_csv("Desktop/Data Analysis by Python/crop_yield.csv")
df
# Out:
#        Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0        West     Sandy   Cotton   897.077239            27.676966
# 1       South      Clay     Rice   992.673282            18.026142
# 2       North      Loam   Barley   147.998025            29.794042
# 3       North     Sandy  Soybean   986.866331            16.644190
# 4       South      Silt    Wheat   730.379174            31.620687
# ...       ...       ...      ...          ...                  ...
# 999995   West      Silt     Rice   302.805345            27.987428
# 999996  South    Chalky   Barley   932.991383            39.661039
# 999997  North     Peaty   Cotton   867.362046            24.370042
# 999998   West      Silt    Wheat   492.812857            33.045505
# 999999   West     Sandy    Maize   180.936180            27.298847
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0                 False             True            Cloudy              122
# ...

# %%
#ti describe the all numeric data set
df .describe ()
# Out:
#           Rainfall_mm  Temperature_Celsius  Days_to_Harvest  \
# count  1000000.000000       1000000.000000   1000000.000000
# mean       549.981901            27.504965       104.495025
# std        259.851320             7.220608        25.953412
# min        100.000896            15.000034        60.000000
# 25%        324.891090            21.254502        82.000000
# 50%        550.124061            27.507365       104.000000
# 75%        774.738520            33.753267       127.000000
# max        999.998098            39.999997       149.000000
#
#        Yield_tons_per_hectare
# count          1000000.000000
# mean                 4.649472
# std                  1.696572
# min                 -1.147613
# 25%                  3.417637
# 50%                  4.651808
# 75%                  5.879200
# max                  9.963372

# %%
#to describe specific column
df .Yield_tons_per_hectare .describe()
# Out:
# count    1000000.000000
# mean           4.649472
# std            1.696572
# min           -1.147613
# 25%            3.417637
# 50%            4.651808
# 75%            5.879200
# max            9.963372
# Name: Yield_tons_per_hectare, dtype: float64

# %%
# for string data set: some info like which word has highest frequency -north
df .Region.describe()
# Out:
# count     1000000
# unique          4
# top         North
# freq       250173
# Name: Region, dtype: object

# %%
# to see the mean of specific column
df .Rainfall_mm .mean()
# Out:
# 549.981900729363

# %%
df .Region.unique()
# Out:
# array(['West', 'South', 'North', 'East'], dtype=object)

# %%
# to see the frequency of all the string value or unique value
df .Region.value_counts()
# Out:
# Region
# North    250173
# West     250074
# South    250054
# East     249699
# Name: count, dtype: int64

# %%
df .Temperature_Celsius.median()
# Out:
# 27.50736543143337

# %%
df .Weather_Condition .unique()
# Out:
# array(['Cloudy', 'Rainy', 'Sunny'], dtype=object)

# %%
df .Weather_Condition.value_counts()
# Out:
# Weather_Condition
# Sunny     333790
# Rainy     333561
# Cloudy    332649
# Name: count, dtype: int64

# %%
# data normalization (centering transformation)
centered_yield = df .Yield_tons_per_hectare - df.Yield_tons_per_hectare.mean()
centered_yield
# Out:
# 0         1.906344
# 1         3.877868
# 2        -3.522029
# 3         1.868100
# 4         2.598779
#             ...
# 999995   -3.301887
# 999996    2.662122
# 999997    1.113709
# 999998   -2.579314
# 999999   -1.712229
# Name: Yield_tons_per_hectare, Length: 1000000, dtype: float64

# %%
df = pd .read_csv ("Desktop/Data Analysis by Python/winemag-data-130k-v2.csv")
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df .dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
df .points.dtypes
# Out:
# dtype('float64')

# %%
df .points = df .points.astype('float')

# %%
print (df .points.dtype)
# Out:
# float64

# %%
#rename
df .rename (columns={'points':'score'})
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df .score.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5688\2987059809.py in ?()
# ----> 1 df .score.dtypes
#
# D:\Anaconda for Python\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'score'

# %%
#to store the change
df = df .rename (columns={'points':'score'})

# %%
df .score.dtypes
# Out:
# dtype('float64')

# %%
df .rename (index={0:'first_entry',1:'second_entry'})
# Out:
#               Unnamed: 0   country  \
# first_entry            0     Italy
# second_entry           1  Portugal
# 2                      2        US
# 3                      3        US
# 4                      4        US
# ...                  ...       ...
# 129966            129966   Germany
# 129967            129967        US
# 129968            129968    France
# 129969            129969    France
# 129970            129970    France
#
#                                                     description  \
# first_entry   Aromas include tropical fruit, broom, brimston...
# second_entry  This is ripe and fruity, a wine that is smooth...
# 2             Tart and snappy, the flavors of lime flesh and...
# 3             Pineapple rind, lemon pith and orange blossom ...
# 4             Much like the regular bottling from 2012, this...
# ...                                                         ...
# 129966        Notes of honeysuckle and cantaloupe sweeten th...
# ...

# %%
df .rename_axis("wines",axis='rows') .rename_axis("fields", axis='columns')
# Out:
# fields  Unnamed: 0   country  \
# wines
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
# fields                                        description  \
# wines
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df=df .rename(columns={'region_1': 'region', 'region_2':'locale'}) .rename_axis("wines",axis='columns')

# %%
df
# Out:
#         Unnamed: 0   country  \
# wines
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# wines
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...
